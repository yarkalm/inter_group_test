# %%
from time import sleep
import requests
import pandas as pd
import os.path
from datetime import datetime

# %%
if os.path.isfile('dataset.csv'):
    print('dataset.csv exists')
    dataset = pd.read_csv('dataset.csv')
else:
    print('dataset.csv does not exist')
    dataset = pd.DataFrame(columns={'symbol', 'price','time'})
# Out:
# dataset.csv exists

# %%
dataset
# Out:
#          symbol        price                        time
# 0      QTUMUSDT     3.280000     2023-04-15 07:03:52.139
# 1      TUSDUSDT     0.999100     2023-04-15 07:03:52.915
# 2      IOTAUSDT     0.223200     2023-04-15 07:03:53.681
# 3      NULSUSDT     0.277500     2023-04-15 07:03:54.444
# 4      USDCUSDT     0.999100     2023-04-15 07:03:55.205
# ...         ...          ...                         ...
# 11006  BETHUSDT  2083.960000  2023-04-16 16:01:24.896000
# 11007  USTCUSDT     0.022503  2023-04-16 16:01:25.670000
# 11008  PROMUSDT     5.140000  2023-04-16 16:01:26.449000
# 11009  LOOMUSDT     0.065920  2023-04-16 16:01:27.225000
# 11010  RDNTUSDT     0.456300  2023-04-16 16:01:27.986000
#
# [11011 rows x 3 columns]

# %%
key = "https://api.binance.com/api/v1/exchangeInfo"
  
# requesting data from url
data = requests.get(key)  
data = data.json()
print(data)
# Out:
# {'timezone': 'UTC', 'serverTime': 1681657185056, 'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT', 'interval': 'MINUTE', 'intervalNum': 1, 'limit': 1200}, {'rateLimitType': 'ORDERS', 'interval': 'SECOND', 'intervalNum': 10, 'limit': 50}, {'rateLimitType': 'ORDERS', 'interval': 'DAY', 'intervalNum': 1, 'limit': 160000}, {'rateLimitType': 'RAW_REQUESTS', 'interval': 'MINUTE', 'intervalNum': 5, 'limit': 6100}], 'exchangeFilters': [], 'symbols': [{'symbol': 'ETHBTC', 'status': 'TRADING', 'baseAsset': 'ETH', 'baseAssetPrecision': 8, 'quoteAsset': 'BTC', 'quotePrecision': 8, 'quoteAssetPrecision': 8, 'baseCommissionPrecision': 8, 'quoteCommissionPrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'ocoAllowed': True, 'quoteOrderQtyMarketAllowed': True, 'allowTrailingStop': False, 'cancelReplaceAllowed': True, 'isSpotTradingAllowed': True, 'isMarginTradingAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', '
# ...

# %%
currencies = []
for i in data['symbols']:
    if i['symbol'][4:]=='USDT':
        currencies.append(i['symbol'])

# %%
price = "https://api.binance.com/api/v1/ticker/price?symbol="
time = "https://api.binance.com/api/v1/time"


for i in range(0, 10):
    for cur in currencies:
        data = requests.get(price+cur).json()
        symb, cur_price = data['symbol'], data['price']
        tau = requests.get(time).json()['serverTime']
        tau = datetime.fromtimestamp(tau/1000.0).strftime('%Y-%m-%d %H:%M:%S.%f')
        dataset = dataset.append({'symbol':symb, 'price':cur_price, 'time':tau},ignore_index=True)

        #print(f"{symb} price is {cur_price}, time is {tau}")
dataset['time'] = pd.to_datetime(dataset['time'],unit='ms')
# Out:
# C:\Users\yaros\AppData\Local\Temp\ipykernel_14680\2645508844.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append({'symbol':symb, 'price':cur_price, 'time':tau},ignore_index=True)
# C:\Users\yaros\AppData\Local\Temp\ipykernel_14680\2645508844.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append({'symbol':symb, 'price':cur_price, 'time':tau},ignore_index=True)
# C:\Users\yaros\AppData\Local\Temp\ipykernel_14680\2645508844.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append({'symbol':symb, 'price':cur_price, 'time':tau},ignore_index=True)
# ...

# %%
dataset
# Out:
#          symbol          price                        time
# 0      QTUMUSDT           3.28     2023-04-15 07:03:52.139
# 1      TUSDUSDT         0.9991     2023-04-15 07:03:52.915
# 2      IOTAUSDT         0.2232     2023-04-15 07:03:53.681
# 3      NULSUSDT         0.2775     2023-04-15 07:03:54.444
# 4      USDCUSDT         0.9991     2023-04-15 07:03:55.205
# ...         ...            ...                         ...
# 14996  BETHUSDT  2089.30000000  2023-04-16 21:04:14.213000
# 14997  USTCUSDT     0.02259523  2023-04-16 21:04:14.974000
# 14998  PROMUSDT     5.18000000  2023-04-16 21:04:15.763000
# 14999  LOOMUSDT     0.06619000  2023-04-16 21:04:16.545000
# 15000  RDNTUSDT     0.45200000  2023-04-16 21:04:17.302000
#
# [15001 rows x 3 columns]

# %%
dataset.to_csv('dataset.csv',index=False)
